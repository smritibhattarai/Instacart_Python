# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# Creatng path for df
path = r"/content/drive/MyDrive/Pythondataanalytics/Instacartanalysis"

# %%
#importing df
ords_prods_merge = pd.read_pickle(os.path.join(path, '2) Data', 'Prepared data', 'orders_products_merged_updated.pkl'))

# %%
# creating a subset of ords_prods_merge
df =  ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (999993, 20)

# %%
df.head(10)
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    198637   175298    prior             9                   0
# 1      9357     6501    prior            22                   6
# 2   1599735   180044    prior             9                   6
# 3    227255    12074    prior            26                   4
# 4   1675773   192641    prior            11                   0
# 5    372562    28713    prior            11                   6
# 6   3346283     5330    prior            29                   6
# 7   2347216    78418    prior            10                   2
# 8    773678     7175    prior            77                   1
# 9    495805    91827    prior             3                   6
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                 16                    3.0       39812                 23
# 1                 21                   21.0       39812                  7
# 2                 13                   22.0       39812                  4
# 3                 23                    3.0       39812                 23
# 4                 12                   30.0       39812                  1
# 5                 22                    3.0       39812                  3
# 6                 15                    3.0       39812                  2
# 7                 19                    9.0       39812                  5
# 8                 19                    1.0       39812                  2
# 9                 14                   10.0       39812                  9
#
#    reordered   product_name  aisle_id  department_id  prices _merge  \
# 0          0  Organic Thyme        16              4     3.7   both
# 1          1  Organic Thyme        16              4     3.7   both
# 2          0  Organic Thyme        16              4     3.7   both
# 3          1  Organic Thyme        16              4     3.7   both
# 4          1  Organic Thyme        16              4     3.7   both
# 5          0  Organic Thyme        16              4     3.7   both
# 6          1  Organic Thyme        16              4     3.7   both
# 7          0  Organic Thyme        16              4     3.7   both
# 8          1  Organic Thyme        16              4     3.7   both
# 9          0  Organic Thyme        16              4     3.7   both
#
#    price_range_loc    price_range_loc     busiest_day     busiest_days  \
# 0              NaN  Low-range product     Busiest day     Busiest days
# 1              NaN  Low-range product  Regularly busy   Regularly busy
# 2              NaN  Low-range product  Regularly busy   Regularly busy
# 3              NaN  Low-range product      Least busy  Least busy days
# 4              NaN  Low-range product     Busiest day     Busiest days
# 5              NaN  Low-range product  Regularly busy   Regularly busy
# 6              NaN  Low-range product  Regularly busy   Regularly busy
# 7              NaN  Low-range product  Regularly busy   Regularly busy
# 8              NaN  Low-range product  Regularly busy     Busiest days
# 9              NaN  Low-range product  Regularly busy   Regularly busy
#
#   busiest_period_of_day
# 0           Most orders
# 1        Average orders
# 2           Most orders
# 3         Fewest orders
# 4           Most orders
# 5        Average orders
# 6           Most orders
# 7        Average orders
# 8        Average orders
# 9           Most orders

# %%
# Grouping Data with pandas
df.groupby('product_name')

# %%
# Aggregating Data with agg()
df.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.411964
# 2                17.937332
# 3                17.350809
# 4                17.832772
# 5                15.448580
# 6                16.641961
# 7                17.255368
# 8                15.101896
# 9                16.024819
# 10               20.873521
# 11               16.114689
# 12               15.850550
# 13               16.578353
# 14               16.823920
# 15               16.319804
# 16               17.674026
# 17               15.775863
# 18               19.339261
# 19               17.141572
# 20               16.490528
# 21               23.120151

# %%
# Performing Multiple aggregations
df.groupby('department_id').agg({'order_number' : ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.411964   1  99
# 2                17.937332   1  96
# 3                17.350809   1  99
# 4                17.832772   1  99
# 5                15.448580   1  99
# 6                16.641961   1  99
# 7                17.255368   1  99
# 8                15.101896   1  95
# 9                16.024819   1  99
# 10               20.873521   1  96
# 11               16.114689   1  99
# 12               15.850550   1  99
# 13               16.578353   1  99
# 14               16.823920   1  99
# 15               16.319804   1  99
# 16               17.674026   1  99
# 17               15.775863   1  99
# 18               19.339261   1  99
# 19               17.141572   1  99
# 20               16.490528   1  99
# 21               23.120151   1  99

# %% [markdown]
# # Create a loyalty flag using loc

# %%
# Aggregating Data with transform
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0     198637   175298    prior             9                   0
# 1       9357     6501    prior            22                   6
# 2    1599735   180044    prior             9                   6
# 3     227255    12074    prior            26                   4
# 4    1675773   192641    prior            11                   0
# 5     372562    28713    prior            11                   6
# 6    3346283     5330    prior            29                   6
# 7    2347216    78418    prior            10                   2
# 8     773678     7175    prior            77                   1
# 9     495805    91827    prior             3                   6
# 10    484410   119960    prior             4                   1
# 11    181733    79785    prior            24                   4
# 12     25566   111488    prior             4                   4
# 13   1552437   150620    prior             2                   2
# 14   1332142   182401    prior             8                   2
#
#     order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  16                    3.0       39812                 23
# 1                  21                   21.0       39812                  7
# 2                  13                   22.0       39812                  4
# 3                  23                    3.0       39812                 23
# 4                  12                   30.0       39812                  1
# 5                  22                    3.0       39812                  3
# 6                  15                    3.0       39812                  2
# 7                  19                    9.0       39812                  5
# 8                  19                    1.0       39812                  2
# 9                  14                   10.0       39812                  9
# 10                  3                   12.0       39812                 11
# 11                  9                   12.0       39812                  6
# 12                 11                   13.0       39812                  3
# 13                 16                   21.0       39812                 10
# 14                 13                    2.0       39812                  8
#
#     reordered  ... aisle_id  department_id  prices  _merge  price_range_loc  \
# 0           0  ...       16              4     3.7    both              NaN
# 1           1  ...       16              4     3.7    both              NaN
# 2           0  ...       16              4     3.7    both              NaN
# 3           1  ...       16              4     3.7    both              NaN
# 4           1  ...       16              4     3.7    both              NaN
# 5           0  ...       16              4     3.7    both              NaN
# 6           1  ...       16              4     3.7    both              NaN
# 7           0  ...       16              4     3.7    both              NaN
# 8           1  ...       16              4     3.7    both              NaN
# 9           0  ...       16              4     3.7    both              NaN
# 10          0  ...       16              4     3.7    both              NaN
# 11          0  ...       16              4     3.7    both              NaN
# 12          0  ...       16              4     3.7    both              NaN
# 13          0  ...       16              4     3.7    both              NaN
# 14          1  ...       16              4     3.7    both              NaN
#
#       price_range_loc     busiest_day     busiest_days busiest_period_of_day  \
# 0   Low-range product     Busiest day     Busiest days           Most orders
# 1   Low-range product  Regularly busy   Regularly busy        Average orders
# 2   Low-range product  Regularly busy   Regularly busy           Most orders
# 3   Low-range product      Least busy  Least busy days         Fewest orders
# 4   Low-range product     Busiest day     Busiest days           Most orders
# 5   Low-range product  Regularly busy   Regularly busy        Average orders
# 6   Low-range product  Regularly busy   Regularly busy           Most orders
# 7   Low-range product  Regularly busy   Regularly busy        Average orders
# 8   Low-range product  Regularly busy     Busiest days        Average orders
# 9   Low-range product  Regularly busy   Regularly busy           Most orders
# 10  Low-range product  Regularly busy     Busiest days         Fewest orders
# 11  Low-range product      Least busy  Least busy days           Most orders
# 12  Low-range product      Least busy  Least busy days           Most orders
# 13  Low-range product  Regularly busy   Regularly busy           Most orders
# 14  Low-range product  Regularly busy   Regularly busy           Most orders
#
#    max_order
# 0         38
# 1         28
# 2         12
# 3         30
# 4         11
# 5         12
# 6         43
# 7         18
# 8         95
# 9         29
# 10         4
# 11        24
# 12        70
# 13        12
# 14        98
#
# [15 rows x 21 columns]

# %%
#Deriving coulmns with loc()
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    468652
# Loyal customer      295165
# New customer        236176
# Name: loyalty_flag, dtype: int64

# %%
# checking the columns
ords_prods_merge[['user_id', 'order_number', 'loyalty_flag']].sample(30)
# Out:
#         user_id  order_number      loyalty_flag
# 473775    68428             2  Regular customer
# 72516    173897            35    Loyal customer
# 803932    26185             1  Regular customer
# 226291   105939            68    Loyal customer
# 715393    32914            15  Regular customer
# 740653    22429             7      New customer
# 339881    28894            12  Regular customer
# 52241     71034            26  Regular customer
# 335712   178896            16  Regular customer
# 903805   194372             7  Regular customer
# 203718    46186             1    Loyal customer
# 832169    10066             3  Regular customer
# 161469   188763            52    Loyal customer
# 602525     2518            16  Regular customer
# 838157   166002             2    Loyal customer
# 958984   148802             1      New customer
# 468871    16312            11    Loyal customer
# 975319   199471             9  Regular customer
# 600635    71862             3      New customer
# 79828    181153            25    Loyal customer
# 658331   105065             3      New customer
# 170281    95236            47    Loyal customer
# 977711    93411             5  Regular customer
# 314460   113197             2      New customer
# 88593     13408             5  Regular customer
# 677705    23313             9  Regular customer
# 880436   204785             4      New customer
# 371474   143686            40    Loyal customer
# 81811     85247            11    Loyal customer
# 702016    46400            16  Regular customer

# %% [markdown]
# #4.8 Task

# %%
#finding the aggregated mean of the "order_number" column grouped by the "department_id"
ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.411964
# 2                17.937332
# 3                17.350809
# 4                17.832772
# 5                15.448580
# 6                16.641961
# 7                17.255368
# 8                15.101896
# 9                16.024819
# 10               20.873521
# 11               16.114689
# 12               15.850550
# 13               16.578353
# 14               16.823920
# 15               16.319804
# 16               17.674026
# 17               15.775863
# 18               19.339261
# 19               17.141572
# 20               16.490528
# 21               23.120151

# %%
# reran df for comparison
df.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.411964
# 2                17.937332
# 3                17.350809
# 4                17.832772
# 5                15.448580
# 6                16.641961
# 7                17.255368
# 8                15.101896
# 9                16.024819
# 10               20.873521
# 11               16.114689
# 12               15.850550
# 13               16.578353
# 14               16.823920
# 15               16.319804
# 16               17.674026
# 17               15.775863
# 18               19.339261
# 19               17.141572
# 20               16.490528
# 21               23.120151

# %% [markdown]
# Q3. how do the results for the entire dataframe differ from those of the subset? Mean from the order_number are larger and are less variable than the mean for the entire data set

# %% [markdown]
# Q4. Create a loyalty flag for existing customers using the transform() and loc() functions?
# Already completed above

# %% [markdown]
# Q5. Basic stats of product prices for each loyalty category

# %%
# finding the mean, maximum, and minimum for the 3 loyalty categories
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.385076  1.0  99999.0
# New customer      14.114389  1.0  99999.0
# Regular customer  11.886113  1.0  99999.0

# %% [markdown]
# Q6. Create a spending flag for each user based on the average price across all their orders

# %%
# creating "average_price" column
ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    198637   175298    prior             9                   0
# 1      9357     6501    prior            22                   6
# 2   1599735   180044    prior             9                   6
# 3    227255    12074    prior            26                   4
# 4   1675773   192641    prior            11                   0
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                 16                    3.0       39812                 23
# 1                 21                   21.0       39812                  7
# 2                 13                   22.0       39812                  4
# 3                 23                    3.0       39812                 23
# 4                 12                   30.0       39812                  1
#
#    reordered  ... prices  _merge   price_range_loc    price_range_loc  \
# 0          0  ...    3.7    both               NaN  Low-range product
# 1          1  ...    3.7    both               NaN  Low-range product
# 2          0  ...    3.7    both               NaN  Low-range product
# 3          1  ...    3.7    both               NaN  Low-range product
# 4          1  ...    3.7    both               NaN  Low-range product
#
#       busiest_day     busiest_days busiest_period_of_day max_order  \
# 0     Busiest day     Busiest days           Most orders        38
# 1  Regularly busy   Regularly busy        Average orders        28
# 2  Regularly busy   Regularly busy           Most orders        12
# 3      Least busy  Least busy days         Fewest orders        30
# 4     Busiest day     Busiest days           Most orders        11
#
#        loyalty_flag average_price
# 0  Regular customer      6.188235
# 1  Regular customer      7.775000
# 2  Regular customer      4.885714
# 3  Regular customer      7.761111
# 4  Regular customer      3.700000
#
# [5 rows x 23 columns]

# %%
# creating "Spending_flag" for average price < 10 as low spender
ords_prods_merge.loc[ords_prods_merge['average_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
#creating "Spending_flag" for average price >= 10 as High spender
ords_prods_merge.loc[ords_prods_merge['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     905650
# High spender     94343
# Name: spending_flag, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    198637   175298    prior             9                   0
# 1      9357     6501    prior            22                   6
# 2   1599735   180044    prior             9                   6
# 3    227255    12074    prior            26                   4
# 4   1675773   192641    prior            11                   0
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                 16                    3.0       39812                 23
# 1                 21                   21.0       39812                  7
# 2                 13                   22.0       39812                  4
# 3                 23                    3.0       39812                 23
# 4                 12                   30.0       39812                  1
#
#    reordered  ... _merge   price_range_loc    price_range_loc     busiest_day  \
# 0          0  ...   both               NaN  Low-range product     Busiest day
# 1          1  ...   both               NaN  Low-range product  Regularly busy
# 2          0  ...   both               NaN  Low-range product  Regularly busy
# 3          1  ...   both               NaN  Low-range product      Least busy
# 4          1  ...   both               NaN  Low-range product     Busiest day
#
#       busiest_days busiest_period_of_day max_order      loyalty_flag  \
# 0     Busiest days           Most orders        38  Regular customer
# 1   Regularly busy        Average orders        28  Regular customer
# 2   Regularly busy           Most orders        12  Regular customer
# 3  Least busy days         Fewest orders        30  Regular customer
# 4     Busiest days           Most orders        11  Regular customer
#
#   average_price spending_flag
# 0      6.188235   Low spender
# 1      7.775000   Low spender
# 2      4.885714   Low spender
# 3      7.761111   Low spender
# 4      3.700000   Low spender
#
# [5 rows x 24 columns]

# %% [markdown]
# Q7. Create order frequency flag that marks the regularity of a user's ordering behavior

# %%
# creating "median_orders" column
ords_prods_merge['median_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.median)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    198637   175298    prior             9                   0
# 1      9357     6501    prior            22                   6
# 2   1599735   180044    prior             9                   6
# 3    227255    12074    prior            26                   4
# 4   1675773   192641    prior            11                   0
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                 16                    3.0       39812                 23
# 1                 21                   21.0       39812                  7
# 2                 13                   22.0       39812                  4
# 3                 23                    3.0       39812                 23
# 4                 12                   30.0       39812                  1
#
#    reordered  ...  price_range_loc    price_range_loc     busiest_day  \
# 0          0  ...              NaN  Low-range product     Busiest day
# 1          1  ...              NaN  Low-range product  Regularly busy
# 2          0  ...              NaN  Low-range product  Regularly busy
# 3          1  ...              NaN  Low-range product      Least busy
# 4          1  ...              NaN  Low-range product     Busiest day
#
#       busiest_days busiest_period_of_day max_order      loyalty_flag  \
# 0     Busiest days           Most orders        38  Regular customer
# 1   Regularly busy        Average orders        28  Regular customer
# 2   Regularly busy           Most orders        12  Regular customer
# 3  Least busy days         Fewest orders        30  Regular customer
# 4     Busiest days           Most orders        11  Regular customer
#
#   average_price spending_flag median_orders
# 0      6.188235   Low spender           6.0
# 1      7.775000   Low spender          11.5
# 2      4.885714   Low spender          22.0
# 3      7.761111   Low spender          21.0
# 4      3.700000   Low spender          30.0
#
# [5 rows x 25 columns]

# %%
# Creating "order_frequency_flag" for median_orders > 20 as "Non-frequent customer"
ords_prods_merge.loc[ords_prods_merge['median_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
# Creating "order_frequency_flag" for median orders > 10 & <= 20 as "Regular customer"
ords_prods_merge.loc[(ords_prods_merge['median_orders'] > 10) & (ords_prods_merge['median_orders'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
# Creating "order_frequency_flag" for median orders < 10 as "Frequent customer"
ords_prods_merge.loc[ords_prods_merge['median_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# checking "order_frequency_flag" frequency
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        650341
# Regular customer         213732
# Non-frequent customer    126269
# NaN                        9651
# Name: order_frequency_flag, dtype: int64

# %% [markdown]
# Q9. Export dataframe as pickle file and store it in your "Prepared Data" folder

# %%
ords_prods_merge.to_pickle(os.path.join(path, '2) Data', 'Prepared data', 'orders_products_merged_updated_2.0.pkl'))
